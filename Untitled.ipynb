# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("train.csv")

# %%
data.head()
# Out:
#       Feature    Name
# 0   64.173835  Arslan
# 1  180.705917   Ahmad
# 2  158.839613   Ahmad
# 3   18.594159  Arslan
# 4   34.871981  Arslan

# %%
data.shape
# Out:
# (160, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Feature  160 non-null    float64
#  1   Name     160 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 2.6+ KB

# %%
x = data.drop("Name",axis = 1)

# %%
x
# Out:
#         Feature
# 0     64.173835
# 1    180.705917
# 2    158.839613
# 3     18.594159
# 4     34.871981
# ..          ...
# 155  173.378363
# 156  103.638730
# 157   10.220539
# 158  127.202845
# 159   38.811896
#
# [160 rows x 1 columns]

# %%
x.head
# Out:
# <bound method NDFrame.head of         Feature
# 0     64.173835
# 1    180.705917
# 2    158.839613
# 3     18.594159
# 4     34.871981
# ..          ...
# 155  173.378363
# 156  103.638730
# 157   10.220539
# 158  127.202845
# 159   38.811896
#
# [160 rows x 1 columns]>

# %%
y= data["Name"]

# %%
y.head()
# Out:
# 0    Arslan
# 1     Ahmad
# 2     Ahmad
# 3    Arslan
# 4    Arslan
# Name: Name, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3 )

# %%
x_train.shape
# Out:
# (112, 1)

# %%
y_train.shape
# Out:
# (112,)

# %%
x_test.shape
# Out:
# (48, 1)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[50]])
# Out:
# c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Arslan'], dtype=object)

# %%
import pickle
pickle.dump(model,open('model1.pkl','wb'))

# %%
with open('classifier.pkl','rb') as file:
    clf = pickle.load(file)

# %%
prediction = clf.predict([[50]])

# %%
prediction
# Out:
# array(['Arslan'], dtype=object)

# %%
from flask import Flask

# %%
app = Flask(__name__)

# %%
import pickle

model = pickle.load(open('classifier.pkl', 'rb'))
# Load the model from the .pkl file
# with open('classifier.pkl', 'rb') as model_file:
#     model = pickle.load(model_file)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pickle
# ----> 3 model = pickle.load(open('classifier.pkl', 'rb'))
#       4 # Load the model from the .pkl file
#       5 # with open('classifier.pkl', 'rb') as model_file:
#       6 #     model = pickle.load(model_file)
#
# EOFError: Ran out of input

# %%
# Import necessary libraries
from flask import Flask, request, jsonify
from threading import Thread

# Create a Flask application
app = Flask(__name__)


@app.route('/')
def home():
    return "Hello World"

# Define a route for POST requests
@app.route('/predict', methods=['POST'])
def predict():
    # Get JSON data from the request
    # data = request.get_json()
    # feature = request.form.get('feature')
    input_query = np.array([[Feature]])
    result = model.predict(input_query)[0]
    # Mock prediction logic (replace with your model's prediction call)
    # prediction = {"result": feature}
    # prediction = model.predict([[feature]])
    return jsonify({"results": str(result)})

    # Return the prediction as a JSON response
    # return jsonify(prediction)

# Function to run the Flask app
def run_app():
    app.run(host='0.0.0.0', port=5000, debug=True, use_reloader=False)

# Start the Flask app in a separate thread to avoid blocking the notebook
flask_thread = Thread(target=run_app)
flask_thread.start()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.10.7:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Apr/2024 08:15:26] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1498, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1476, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "C:\Users\Arslan\AppData\Local\Temp\ipykernel_6844\1675746914.py", line 19, in predict
#     input_query = np.array([[Feature]])
# NameError: name 'Feature' is not defined
# 127.0.0.1 - - [28/Apr/2024 08:15:28] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1498, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1476, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "C:\Users\Arslan\AppData\Local\Temp\ipykernel_6844\1675746914.py", line 19, in predict
#     input_query = np.array([[Feature]])
# NameError: name 'Feature' is not defined
# 127.0.0.1 - - [28/Apr/2024 08:15:29] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1498, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1476, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "C:\Users\Arslan\AppData\Local\Temp\ipykernel_6844\1675746914.py", line 19, in predict
#     input_query = np.array([[Feature]])
# NameError: name 'Feature' is not defined
# 127.0.0.1 - - [28/Apr/2024 08:15:35] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1498, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1476, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "C:\Users\Arslan\AppData\Local\Temp\ipykernel_6844\1675746914.py", line 19, in predict
#     input_query = np.array([[Feature]])
# NameError: name 'Feature' is not defined
# 127.0.0.1 - - [28/Apr/2024 08:15:36] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1498, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1476, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "C:\Users\Arslan\AppData\Local\Temp\ipykernel_6844\1675746914.py", line 19, in predict
#     input_query = np.array([[Feature]])
# NameError: name 'Feature' is not defined
# 127.0.0.1 - - [28/Apr/2024 08:15:36] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1498, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1476, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "C:\Users\Arslan\AppData\Local\Temp\ipykernel_6844\1675746914.py", line 19, in predict
#     input_query = np.array([[Feature]])
# NameError: name 'Feature' is not defined
# 127.0.0.1 - - [28/Apr/2024 08:15:37] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1498, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1476, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "C:\Users\Arslan\AppData\Local\Temp\ipykernel_6844\1675746914.py", line 19, in predict
#     input_query = np.array([[Feature]])
# NameError: name 'Feature' is not defined
# 127.0.0.1 - - [28/Apr/2024 08:15:37] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1498, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1476, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "C:\Users\Arslan\AppData\Local\Temp\ipykernel_6844\1675746914.py", line 19, in predict
#     input_query = np.array([[Feature]])
# NameError: name 'Feature' is not defined
# 127.0.0.1 - - [28/Apr/2024 08:15:38] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1498, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1476, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "C:\Users\Arslan\AppData\Local\Temp\ipykernel_6844\1675746914.py", line 19, in predict
#     input_query = np.array([[Feature]])
# NameError: name 'Feature' is not defined
# 127.0.0.1 - - [28/Apr/2024 08:15:39] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1498, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1476, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "C:\Users\Arslan\AppData\Local\Temp\ipykernel_6844\1675746914.py", line 19, in predict
#     input_query = np.array([[Feature]])
# NameError: name 'Feature' is not defined
# 127.0.0.1 - - [28/Apr/2024 08:15:39] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1498, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1476, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\users\arslan\appdata\local\programs\python\python39\lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "C:\Users\Arslan\AppData\Local\Temp\ipykernel_6844\1675746914.py", line 19, in predict
#     input_query = np.array([[Feature]])
# NameError: name 'Feature' is not defined
